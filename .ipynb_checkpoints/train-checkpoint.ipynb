# %%
import sys, os  
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import regularizers, optimizers
import numpy as np

# %% [markdown]
# - Chia bộ dữ liệu có được thành dữ liệu training và dữ liệu test theo code sau:

# %%
df=pd.read_csv('/content/drive/MyDrive/Nhandiencamxuc/fer2013.csv')  
X_train,train_y,X_test,test_y=[],[],[],[]  
for index, row in df.iterrows():  
    val=row['pixels'].split(" ")  
    try:  
        if 'Training' in row['Usage']:  
           X_train.append(np.array(val,'float32'))  
           train_y.append(row['emotion'])  
        elif 'PublicTest' in row['Usage']:  
           X_test.append(np.array(val,'float32'))  
           test_y.append(row['emotion'])  
    except:  
        print(f"error occured at index :{index} and row:{row}")

# %%
print(X_train[0:1])
#X_train.shape()
print(train_y[0:50])
# Out:
# [array([ 70.,  80.,  82., ..., 106., 109.,  82.], dtype=float32)]
# [0, 0, 2, 4, 6, 2, 4, 3, 3, 2, 0, 6, 6, 6, 3, 5, 3, 2, 6, 4, 4, 2, 0, 0, 3, 3, 5, 0, 3, 5, 3, 6, 3, 2, 3, 6, 6, 6, 0, 5, 0, 3, 4, 0, 6, 2, 3, 6, 2, 2]

# %% [markdown]
# - Sau khi load xong dữ liệu và chia dữ liệu thành training và test thì mình cần xử lý dữ liệu và chuyển y thành dạng category:

# %%
data = np.load("dataset.npz")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-041e2cb6cd05> in <module>()
# ----> 1 data = np.load("dataset.npz")
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset.npz'

# %%
X = data['X']
Y = data['Y']

# %%
mean = np.mean(X)
std  = np.std(X)
X = (X-mean)/(std+1e-7)

# %%
split = 0.8
sizeData = X.shape[0]

# %%
'''
Với kiểu dữ liệu numpy và ít dữ liệu bạn có thể làm như thế này.
'''
seed = 113
rng = np.random.RandomState(seed) # Dữ nguyên trạng thái random với seed bất kỳ
indices = np.arange(sizeData)
rng.shuffle(indices)
X = X[indices]
Y = Y[indices]

# %%
# split dataset to test, train
split = int(sizeData*split)
trainX = X[:split]
testX = X[split:]
trainY = Y[:split]
testY = Y[split:]

# %%
num_labels = 4 
batch_size = 16 
epochs = 100 
width, height = 48, 48  


trainX = trainX.reshape(trainX.shape[0], 48, 48, 1)  
testX = testX.reshape(testX.shape[0], 48, 48, 1)

# %%
baseMapNum = 32
weight_decay = 1e-5

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizers.l1_l2(weight_decay, weight_decay), input_shape=trainX.shape[1:]))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), padding='same', activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizers.l1_l2(weight_decay, weight_decay)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(64, (3,3), padding='same', activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizers.l1_l2(weight_decay, weight_decay)))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), padding='same', activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizers.l1_l2(weight_decay, weight_decay)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(128, (3,3), padding='same', activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizers.l1_l2(weight_decay, weight_decay)))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), padding='same', activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizers.l1_l2(weight_decay, weight_decay)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, (3,3), padding='same', activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizers.l1_l2(weight_decay, weight_decay)))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), padding='same', activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizers.l1_l2(weight_decay, weight_decay)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(num_labels, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_32 (Conv2D)           (None, 48, 48, 32)        320
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 48, 48, 32)        128
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 48, 48, 32)        9248
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 48, 48, 32)        128
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 24, 24, 32)        0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 24, 24, 64)        18496
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 24, 24, 64)        256
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 24, 24, 64)        36928
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 24, 24, 64)        256
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 12, 12, 128)       73856
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 12, 12, 128)       512
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 12, 12, 128)       147584
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 12, 12, 128)       512
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 6, 6, 128)         147584
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 6, 6, 128)         512
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 6, 6, 128)         147584
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 6, 6, 128)         512
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 3, 3, 128)         0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               147584
# _________________________________________________________________
# dense_9 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 732,516
# Trainable params: 731,108
# Non-trainable params: 1,408
# _________________________________________________________________

# %% [markdown]
# - B4: Training mô hình

# %%
#training
batch_size = 256
epochs = 150
steps = trainX.shape[0] // batch_size

boundaries = [steps*70, steps*110]
values = [0.001, 0.0005, 0.0001]
schedules = keras.optimizers.schedules.PiecewiseConstantDecay(boundaries, values)
opt_adam  = keras.optimizers.Adam(learning_rate=schedules)

# %%
# data augmentation
train_dataset = tf.data.Dataset.from_tensor_slices((trainX, trainY))
test_dataset  = tf.data.Dataset.from_tensor_slices((testX, testY))

def process_data(image, label):
    # if tf.random.uniform(()) > 0.5:
    #     image = tf.image.resize(image, (38, 38))
    #     image = tf.image.random_crop(image, size=[32, 32, 3])
        
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_left_right(image)

    return image, label

train_batches = (train_dataset.shuffle(256*4)
                              .map(process_data, num_parallel_calls=tf.data.experimental.AUTOTUNE)
                              .batch(batch_size)
                              .prefetch(tf.data.experimental.AUTOTUNE) )

test_dataset = (test_dataset.batch(batch_size))

model.compile(loss='sparse_categorical_crossentropy', optimizer=opt_adam, metrics=['accuracy'])
history = model.fit(train_batches, validation_data=test_dataset, epochs=epochs, verbose=1)
# Out:
# Epoch 1/150
# 6/6 [==============================] - 2s 123ms/step - loss: 3.2680 - accuracy: 0.3124 - val_loss: 9.9112 - val_accuracy: 0.3188
# Epoch 2/150
# 6/6 [==============================] - 0s 65ms/step - loss: 2.0210 - accuracy: 0.3560 - val_loss: 4.5570 - val_accuracy: 0.1771
# Epoch 3/150
# 6/6 [==============================] - 0s 65ms/step - loss: 1.7121 - accuracy: 0.4133 - val_loss: 8.2012 - val_accuracy: 0.3188
# Epoch 4/150
# 6/6 [==============================] - 0s 65ms/step - loss: 1.5355 - accuracy: 0.4707 - val_loss: 5.7821 - val_accuracy: 0.3188
# Epoch 5/150
# 6/6 [==============================] - 0s 65ms/step - loss: 1.4632 - accuracy: 0.4846 - val_loss: 3.0031 - val_accuracy: 0.3270
# Epoch 6/150
# 6/6 [==============================] - 0s 65ms/step - loss: 1.4798 - accuracy: 0.4843 - val_loss: 2.8595 - val_accuracy: 0.3351
# Epoch 7/150
# 6/6 [==============================] - 0s 65ms/step - loss: 1.4464 - accuracy: 0.5008 - val_loss: 2.0507 - val_accuracy: 0.3460
# Epoch 8/150
# 6/6 [==============================] - 0s 66ms/step - loss: 1.3812 - accuracy: 0.5440 - val_loss: 1.6330 - val_accuracy: 0.3951
# Epoch 9/150
# 6/6 [==============================] - 0s 64ms/step - loss: 1.3642 - accuracy: 0.5417 - val_loss: 1.5798 - val_accuracy: 0.3406
# Epoch 10/150
# 6/6 [==============================] - 0s 65ms/step - loss: 1.3448 - accuracy: 0.5554 - val_loss: 1.5327 - val_accuracy: 0.3924
# Epoch 11/150
# 6/6 [==============================] - 0s 65ms/step - loss: 1.3270 - accuracy: 0.5509 - val_loss: 1.4929 - val_accuracy: 0.4850
# Epoch 12/150
# 6/6 [==============================] - 0s 65ms/step - loss: 1.3067 - accuracy: 0.5707 - val_loss: 1.4708 - val_accuracy: 0.4823
# Epoch 13/150
# 6/6 [==============================] - 0s 66ms/step - loss: 1.2715 - accuracy: 0.5900 - val_loss: 1.4575 - val_accuracy: 0.5068
# Epoch 14/150
# 6/6 [==============================] - 0s 65ms/step - loss: 1.2503 - accuracy: 0.5807 - val_loss: 1.5103 - val_accuracy: 0.4714
# Epoch 15/150
# 6/6 [==============================] - 0s 66ms/step - loss: 1.2368 - accuracy: 0.5949 - val_loss: 1.5512 - val_accuracy: 0.4687
# Epoch 16/150
# 6/6 [==============================] - 0s 65ms/step - loss: 1.2052 - accuracy: 0.6059 - val_loss: 1.4758 - val_accuracy: 0.5014
# Epoch 17/150
# 6/6 [==============================] - 0s 66ms/step - loss: 1.1617 - accuracy: 0.6194 - val_loss: 1.5087 - val_accuracy: 0.5177
# Epoch 18/150
# 6/6 [==============================] - 0s 65ms/step - loss: 1.1637 - accuracy: 0.6337 - val_loss: 1.4703 - val_accuracy: 0.5259
# Epoch 19/150
# 6/6 [==============================] - 0s 65ms/step - loss: 1
150
# 6/6 [==============================] - 0s 66ms/step - loss: 0.3397 - accuracy: 0.9733 - val_loss: 1.1449 - val_accuracy: 0.8011
# Epoch 133/150
# 6/6 [==============================] - 0s 69ms/step - loss: 0.3546 - accuracy: 0.9620 - val_loss: 1.1212 - val_accuracy: 0.7984
# Epoch 134/150
# 6/6 [==============================] - 0s 67ms/step - loss: 0.3613 - accuracy: 0.9604 - val_loss: 1.1396 - val_accuracy: 0.7929
# Epoch 135/150
# 6/6 [==============================] - 0s 67ms/step - loss: 0.3712 - accuracy: 0.9555 - val_loss: 1.1822 - val_accuracy: 0.7875
# Epoch 136/150
# 6/6 [==============================] - 0s 67ms/step - loss: 0.3637 - accuracy: 0.9605 - val_loss: 1.1873 - val_accuracy: 0.7820
# Epoch 137/150
# 6/6 [==============================] - 0s 68ms/step - loss: 0.3578 - accuracy: 0.9541 - val_loss: 1.1602 - val_accuracy: 0.7875
# Epoch 138/150
# 6/6 [==============================] - 0s 68ms/step - loss: 0.3535 - accuracy: 0.9673 - val_loss: 1.1496 - val_accuracy: 0.7929
# Epoch 139/150
# 6/6 [==============================] - 0s 67ms/step - loss: 0.3566 - accuracy: 0.9649 - val_loss: 1.1450 - val_accuracy: 0.7929
# Epoch 140/150
# 6/6 [==============================] - 0s 67ms/step - loss: 0.3762 - accuracy: 0.9537 - val_loss: 1.1456 - val_accuracy: 0.7984
# Epoch 141/150
# 6/6 [==============================] - 0s 68ms/step - loss: 0.3634 - accuracy: 0.9537 - val_loss: 1.1468 - val_accuracy: 0.7902
# Epoch 142/150
# 6/6 [==============================] - 0s 67ms/step - loss: 0.3554 - accuracy: 0.9670 - val_loss: 1.1565 - val_accuracy: 0.7902
# Epoch 143/150
# 6/6 [==============================] - 0s 67ms/step - loss: 0.3605 - accuracy: 0.9647 - val_loss: 1.1794 - val_accuracy: 0.7929
# Epoch 144/150
# 6/6 [==============================] - 0s 67ms/step - loss: 0.3596 - accuracy: 0.9581 - val_loss: 1.1773 - val_accuracy: 0.7956
# Epoch 145/150
# 6/6 [==============================] - 0s 66ms/step - loss: 0.3630 - accuracy: 0.9653 - val_loss: 1.1516 - val_accuracy: 0.7929
# Epoch 146/150
# 6/6 [==============================] - 0s 67ms/step - loss: 0.3484 - accuracy: 0.9621 - val_loss: 1.1449 - val_accuracy: 0.7902
# Epoch 147/150
# 6/6 [==============================] - 0s 67ms/step - loss: 0.3515 - accuracy: 0.9618 - val_loss: 1.1434 - val_accuracy: 0.7875
# Epoch 148/150
# 6/6 [==============================] - 0s 67ms/step - loss: 0.3722 - accuracy: 0.9575 - val_loss: 1.1634 - val_accuracy: 0.7847
# Epoch 149/150
# 6/6 [==============================] - 0s 67ms/step - loss: 0.3589 - accuracy: 0.9581 - val_loss: 1.1779 - val_accuracy: 0.7929
# Epoch 150/150
# 6/6 [==============================] - 0s 67ms/step - loss: 0.3504 - accuracy: 0.9641 - val_loss: 1.1722 - val_accuracy: 0.7875

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Train loss')
plt.plot(history.history['val_loss'], label = 'Validation val_loss')
plt.legend()

# %%
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
plt.legend()

# %%
#Các bạn thảo luận kĩ hơn về các kĩ thuật training mô hình để tránh overfitting.overfitting.
#Saving the  model 
fer_json = model.to_json()  
with open("fer.json", "w") as json_file:
    json_file.write(fer_json)  
model.save_weights("fer.h5")

# %% [markdown]
# - Detecting Real-Time Emotion

# %%
import os   
import cv2  
import numpy as np  
from keras.models import model_from_json  
from keras.preprocessing import image 
#load model
#model = model_from_json(open("/content/drive/MyDrive/Nhandiencamxuc/fer.json", "r").read())

# %%
with open('fer.json', 'r') as json_file:
  model = model_from_json(json_file.read())

# %%
#load weights  
model.load_weights('fer.h5')  
face_haar_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/Nhandiencamxuc/haarcascade_frontalface_default.xml')

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to photo.jpg

# %%
display(Image(filename))

# %%
from google.colab.patches import cv2_imshow
images = cv2.imread('photo.jpg')
gray_img = cv2.cvtColor(images, cv2.COLOR_BGR2GRAY)
cv2_imshow(images)
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=RGB size=960x720 at 0x7F01F94AC6D8>
# <PIL.Image.Image image mode=L size=960x720 at 0x7F01F94AC390>

# %%
faces_detected = face_haar_cascade.detectMultiScale(gray_img, 1.32, 5) 
#print(gray_img) 
for (x,y,w,h) in faces_detected:
  cv2.rectangle(images,(x,y),(x+w,y+h),(255,0,0),thickness=7)  
  roi_gray=gray_img[y:y+w,x:x+h]#cropping region of interest i.e. face area from  image  
  roi_gray=cv2.resize(roi_gray,(48,48))  
  img_pixels = image.img_to_array(roi_gray)  
  img_pixels = np.expand_dims(img_pixels, axis = 0)  
  img_pixels /= 255  

  predictions = model.predict(img_pixels)  

    #find max indexed array  
  max_index = np.argmax(predictions[0])
  emotions = ('anger', 'happy', 'neutral', 'sad')
  predicted_emotion = emotions[max_index]  

  cv2.putText(images, predicted_emotion, (int(x), int(y)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)  

resized_img = cv2.resize(images, (1000, 700))  
cv2_imshow(resized_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x700 at 0x7F01F9FA7390>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
